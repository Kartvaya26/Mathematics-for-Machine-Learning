# %%
import numpy as np

# %% [markdown]
# Dot Product of 2 vectors

# %%
a = np.array([2, 3])

b = np.array([4, 4])

a_dot_b = np.dot(a, b)

# %%
print(a_dot_b)
# Out:
# 20

# %%
c = np.array([40, 20, 35])

d = np.array([53, 24, 68])

c_dot_d = np.dot(c, d)

# %%
print(c_dot_d)
# Out:
# 4980

# %% [markdown]
# Cross Product of 2 Vectors

# %%
a = np.array([2, 3])

b = np.array([4, 4])

a_cross_b = np.cross(a, b)
# Out:
# /tmp/ipython-input-1135455818.py:5: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   a_cross_b = np.cross(a, b)

# %%
print(a_cross_b)
# Out:
# -4

# %%
a = np.array([5, 10, 20])

b = np.array([18, 32, 50])

a_cross_b = np.cross(a, b)

# %%
print(a_cross_b)
# Out:
# [-140  110  -20]

# %% [markdown]
# Projection of "a" vector on "v" vector

# %% [markdown]
# ![Screenshot 2025-07-31 113147.png](data:image/png;base64,...)
#
# ---

# %%
a = np.array([2, 5])

v = np.array([8, -6])

# magnitude of "V" Vector
magnitude_of_v = np.sqrt(sum(v**2))

proj_of_a_on_v = (np.dot(a,v)/magnitude_of_v**2) * v

print('Projection of a vector on v vector', proj_of_a_on_v)
# Out:
# Projection of a vector on v vector [-1.12  0.84]

# %%
a = np.array([23, 45, 67])

d = np.array([58, 82, 67])

c_dot_d = np.dot(a, d)

# %%
print(c_dot_d)
# Out:
# 9513
